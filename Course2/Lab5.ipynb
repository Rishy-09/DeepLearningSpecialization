# %% [markdown]
# Here is the link to Tensorflow Tutorial that is lab5's activity:

# %% [markdown]
# ## [Tensorflow Tutorial](https://kawshikbuet17.github.io/Coursera-Deep-Learning/02-Improving-Deep-Neural-Networks-Hyperparameter-tuning-Regularization-and-Optimization/Codes/week7/TensorFlow_Tutorial_v3b.html)
